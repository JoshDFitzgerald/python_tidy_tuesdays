# %%
import pandas as pd
from matplotlib import pyplot as plt

df_AllstarFull = pd.read_csv (r'../data/AllstarFull.csv')
df_Appearances = pd.read_csv (r'../data/Appearances.csv')
df_Batting = pd.read_csv (r'../data/Batting.csv')
df_BattingPost = pd.read_csv (r'../data/BattingPost.csv')
df_Fielding = pd.read_csv (r'../data/Fielding.csv')
df_FieldingOF = pd.read_csv (r'../data/FieldingOF.csv')
df_FieldingOFsplit = pd.read_csv (r'../data/FieldingOFsplit.csv')
df_FieldingPost = pd.read_csv (r'../data/FieldingPost.csv')
df_HomeGames = pd.read_csv (r'../data/HomeGames.csv')
df_Managers = pd.read_csv (r'../data/Managers.csv')
df_ManagersHalf = pd.read_csv (r'../data/ManagersHalf.csv')
df_Parks = pd.read_csv (r'../data/Parks.csv')
df_People = pd.read_csv (r'../data/People.csv')
df_Pitching = pd.read_csv (r'../data/Pitching.csv')
df_PitchingPost = pd.read_csv (r'../data/PitchingPost.csv')
df_SeriesPost = pd.read_csv (r'../data/SeriesPost.csv')
df_Teams = pd.read_csv (r'../data/Teams.csv')
df_TeamsFranchises = pd.read_csv (r'../data/TeamsFranchises.csv')
df_TeamsHalf = pd.read_csv (r'../data/TeamsHalf.csv')

# %%
df_People
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0      aardsda01     1981.0        12.0      27.0          USA         CO
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 2      aaronto01     1939.0         8.0       5.0          USA         AL
# 3       aasedo01     1954.0         9.0       8.0          USA         CA
# 4       abadan01     1972.0         8.0      25.0          USA         FL
# ...          ...        ...         ...       ...          ...        ...
# 20587   zupofr01     1939.0         8.0      29.0          USA         CA
# 20588  zuvelpa01     1958.0        10.0      31.0          USA         CA
# 20589  zuverge01     1924.0         8.0      20.0          USA         MI
# 20590  zwilldu01     1888.0        11.0       2.0          USA         MO
# 20591   zychto01     1990.0         8.0       7.0          USA         IL
#
#            birthCity  deathYear  deathMonth  deathDay  ...  nameLast  \
# ...
